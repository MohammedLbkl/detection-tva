# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install transformers==4.46.3 tokenizers==0.20.3 einops addict easydict safetensors
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (2.9.0)
# Requirement already satisfied: torchvision in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (0.24.0)
# Requirement already satisfied: torchaudio in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (2.9.0)
# Requirement already satisfied: filelock in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torchvision) (2.3.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: transformers==4.46.3 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (4.46.3)
# Requirement already satisfied: tokenizers==0.20.3 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (0.20.3)
# Requirement already satisfied: einops in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (0.8.1)
# Requirement already satisfied: addict in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (2.4.0)
# Requirement already satisfied: easydict in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (1.13)
# Requirement already satisfied: safetensors in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (0.6.2)
# Requirement already satisfied: filelock in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (2025.10.23)
# Requirement already satisfied: requests in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (2.32.5)
# Requirement already satisfied: tqdm>=4.27 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from transformers==4.46.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.3) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.3) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.3) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from requests->transformers==4.46.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from requests->transformers==4.46.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from requests->transformers==4.46.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from requests->transformers==4.46.3) (2025.10.5)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoModel, AutoTokenizer
import torch, os

model_name = "deepseek-ai/DeepSeek-OCR"

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

model = AutoModel.from_pretrained(
    model_name,
    trust_remote_code=True,
    use_safetensors=True,
    device_map=None,           # CPU
    torch_dtype=torch.float32  # CPU-safe
)

model = model.eval()
print("✅ Model loaded without Flash-Attention")
# Out:
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Downloading shards:   0%|          | 0/1 [00:00<?, ?it/s]
# model-00001-of-000001.safetensors:   0%|          | 0.00/6.67G [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:626, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     624     progress.update(progress_bytes)
# --> 626 download_files(
#     627     xet_download_info,
#     628     endpoint=connection_info.endpoint,
#     629     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     630     token_refresher=token_refresher,
#     631     progress_updater=[progress_updater],
#     632 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       4 model_name = "deepseek-ai/DeepSeek-OCR"
#       6 tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
# ----> 8 model = AutoModel.from_pretrained(
#       9     model_name,
#      10     trust_remote_code=True,
#      11     use_safetensors=True,
#      12     device_map=None,           # CPU
#      13     torch_dtype=torch.float32  # CPU-safe
#      14 )
#      16 model = model.eval()
#      17 print("✅ Model loaded without Flash-Attention")
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:559, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     557     cls.register(config.__class__, model_class, exist_ok=True)
#     558     model_class = add_generation_mixin_to_remote_model(model_class)
# --> 559     return model_class.from_pretrained(
#     560         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     561     )
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:3974, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3971 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3972 if is_sharded:
#    3973     # resolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3974     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3975         pretrained_model_name_or_path,
#    3976         resolved_archive_file,
#    3977         cache_dir=cache_dir,
#    3978         force_download=force_download,
#    3979         proxies=proxies,
#    3980         resume_download=resume_download,
#    3981         local_files_only=local_files_only,
#    3982         token=token,
#    3983         user_agent=user_agent,
#    3984         revision=revision,
#    3985         subfolder=subfolder,
#    3986         _commit_hash=commit_hash,
#    3987     )
#    3989 if (
#    3990     is_safetensors_available()
#    3991     and isinstance(resolved_archive_file, str)
#    3992     and resolved_archive_file.endswith(".safetensors")
#    3993 ):
#    3994     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:1098, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1095 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1096     try:
#    1097         # Load from URL
# -> 1098         cached_filename = cached_file(
#    1099             pretrained_model_name_or_path,
#    1100             shard_filename,
#    1101             cache_dir=cache_dir,
#    1102             force_download=force_download,
#    1103             proxies=proxies,
#    1104             resume_download=resume_download,
#    1105             local_files_only=local_files_only,
#    1106             token=token,
#    1107             user_agent=user_agent,
#    1108             revision=revision,
#    1109             subfolder=subfolder,
#    1110             _commit_hash=_commit_hash,
#    1111         )
#    1112     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1113     # we don't have to catch them here.
#    1114     except EntryNotFoundError:
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)   1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1168, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1165 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1167 with WeakFileLock(lock_path):
# -> 1168     _download_to_tmp_and_move(
#    1169         incomplete_path=Path(blob_path + ".incomplete"),
#    1170         destination_path=Path(blob_path),
#    1171         url_to_download=url_to_download,
#    1172         proxies=proxies,
#    1173         headers=headers,
#    1174         expected_size=expected_size,
#    1175         filename=filename,
#    1176         force_download=force_download,
#    1177         etag=etag,
#    1178         xet_file_data=xet_file_data,
#    1179     )
#    1180     if not os.path.exists(pointer_path):
#    1181         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1720, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1718 if xet_file_data is not None and is_xet_available():
#    1719     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1720     xet_get(
#    1721         incomplete_path=incomplete_path,
#    1722         xet_file_data=xet_file_data,
#    1723         headers=headers,
#    1724         expected_size=expected_size,
#    1725         displayed_filename=filename,
#    1726     )
#    1727 else:
#    1728     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:621, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     610     displayed_filename = f"{displayed_filename[:40]}(…)"
#     612 progress_cm = _get_progress_bar_context(
#     613     desc=displayed_filename,
#     614     log_level=logger.getEffectiveLevel(),
#    (...)    618     _tqdm_bar=_tqdm_bar,
#     619 )
# --> 621 with progress_cm as progress:
#     623     def progress_updater(progress_bytes: float):
#     624         progress.update(progress_bytes)
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/tqdm/std.py:1138, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1135 def __enter__(self):
#    1136     return self
# -> 1138 def __exit__(self, exc_type, exc_value, traceback):
#    1139     try:
#    1140         self.close()
#
# KeyboardInterrupt:

# %%
prompt = "\n<|grounding|>Convert the document to markdown."
image_file = "../images/test1.png"
output_dir = "results"

os.makedirs(output_dir, exist_ok=True)

res = model.infer(
    tokenizer,
    prompt=prompt,
    image_file=image_file,
    output_path=output_dir,
    base_size=1024,
    image_size=640,
    crop_mode=True,
    save_results=True,
    test_compress=True
)

print(res)
