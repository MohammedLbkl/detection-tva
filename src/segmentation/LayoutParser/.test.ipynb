# %%
# !pip install 'layoutparser[detectron2]'
# Out:
# Collecting layoutparser[detectron2]
#   Downloading layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# WARNING: layoutparser 0.3.4 does not provide the extra 'detectron2'
# Requirement already satisfied: numpy in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from layoutparser[detectron2]) (2.3.4)
# Collecting opencv-python (from layoutparser[detectron2])
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting scipy (from layoutparser[detectron2])
#   Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: pandas in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from layoutparser[detectron2]) (2.3.3)
# Requirement already satisfied: pillow in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from layoutparser[detectron2]) (11.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from layoutparser[detectron2]) (6.0.2)
# Collecting iopath (from layoutparser[detectron2])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pdfplumber (from layoutparser[detectron2])
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
# Collecting pdf2image (from layoutparser[detectron2])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: tqdm in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from iopath->layoutparser[detectron2]) (4.67.1)
# Requirement already satisfied: typing_extensions in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from iopath->layoutparser[detectron2]) (4.15.0)
# Collecting portalocker (from iopath->layoutparser[detectron2])
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting numpy (from layoutparser[detectron2])
#   Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from pandas->layoutparser[detectron2]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from pandas->layoutparser[detectron2]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from pandas->layoutparser[detectron2]) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->layoutparser[detectron2]) (1.17.0)
# Collecting pdfminer.six==20250506 (from pdfplumber->layoutparser[detectron2])
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from pdfplumber->layoutparser[detectron2]) (5.0.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from pdfminer.six==20250506->pdfplumber->layoutparser[detectron2]) (3.4.4)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20250506->pdfplumber->layoutparser[detectron2])
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=2.0.0 in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber->layoutparser[detectron2]) (2.0.0)
# Requirement already satisfied: pycparser in /Users/mohammedlbakali/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber->layoutparser[detectron2]) (2.23)
# Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 4.8 MB/s  0:00:03m0:00:0100:01
# Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 5.0 MB/s  0:00:01 eta 0:00:01
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 5.6 MB/s  0:00:01 eta 0:00:01
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 6.3 MB/s  0:00:03m0:00:0100:01
# Building wheels for collected packages: iopath
#   Building wheel for iopath (pyproject.toml) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31600 sha256=84d9115cabd8942c79f85e96403eaa7d90a2ac101c67f0b9f787d09af756176e
#   Stored in directory: /Users/mohammedlbakali/Library/Caches/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built iopath
# Installing collected packages: portalocker, pdf2image, numpy, scipy, opencv-python, iopath, cryptography, pdfminer.six, pdfplumber, layoutparser
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [layoutparser] [layoutparser]]
# Successfully installed cryptography-46.0.3 iopath-0.1.10 layoutparser-0.3.4 numpy-2.2.6 opencv-python-4.12.0.88 pdf2image-1.17.0 pdfminer.six-20250506 pdfplumber-0.11.7 portalocker-3.2.0 scipy-1.16.3
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import layoutparser as lp
import cv2

# Charger l'image du document
image = cv2.imread("../images/doc1.png")

# Convertir l'image en RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
import layoutparser as lp
import cv2


# Charger l'image
image = cv2.imread("../images/doc1.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Charger le modèle
model = lp.Detectron2LayoutModel(
    config_path='lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config',
    model_path='lp://PubLayNet/faster_rcnn_R_50_FPN_3x/model',
    extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
    label_map={0:"Text", 1:"Title", 2:"List", 3:"Table", 4:"Figure"}
)

# Détecter les blocs
layout = model.detect(image)

# Visualiser
lp.draw_box(image, layout, box_width=3, show_element_type=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 10
#       7 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       9 # Charger le modèle
# ---> 10 model = lp.Detectron2LayoutModel(
#      11     config_path='lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config',
#      12     model_path='lp://PubLayNet/faster_rcnn_R_50_FPN_3x/model',
#      13     extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
#      14     label_map={0:"Text", 1:"Title", 2:"List", 3:"Table", 4:"Figure"}
#      15 )
#      17 # Détecter les blocs
#      18 layout = model.detect(image)
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/layoutparser/file_utils.py:226, in _LazyModule.__getattr__(self, name)
#     224     value = getattr(module, name)
#     225 else:
# --> 226     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#     228 setattr(self, name, value)
#     229 return value
#
# AttributeError: module layoutparser has no attribute Detectron2LayoutModel

# %%
import detectron2
print(detectron2.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import detectron2
#       2 print(detectron2.__version__)
#
# ModuleNotFoundError: No module named 'detectron2'

# %%
import layoutparser as lp
model = lp.Detectron2LayoutModel('lp://HJDataset/faster_rcnn_R_50_FPN_3x/config')
model.detect(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 import layoutparser as lp
# ----> 2 model = lp.Detectron2LayoutModel('lp://HJDataset/faster_rcnn_R_50_FPN_3x/config')
#       3 model.detect(image)
#
# File ~/Desktop/Simoh/detection-tva/.venv/lib/python3.12/site-packages/layoutparser/file_utils.py:226, in _LazyModule.__getattr__(self, name)
#     224     value = getattr(module, name)
#     225 else:
# --> 226     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#     228 setattr(self, name, value)
#     229 return value
#
# AttributeError: module layoutparser has no attribute Detectron2LayoutModel
